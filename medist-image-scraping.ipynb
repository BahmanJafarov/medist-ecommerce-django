# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def download_images(url, folder="image"):
    # Create folder if it doesn't exist
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    headers = {"User-Agent": "Mozilla/5.0"}  # Mimic a browser request
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        print(f"Failed to access {url}")
        return
    
    soup = BeautifulSoup(response.text, "html.parser")
    
    images = soup.find_all("img")
    
    for img in images:
        img_url = img.get("src")
        if img_url and (".png" in img_url or ".jpg" in img_url or ".jpeg" in img_url):
            img_url = urljoin(url, img_url)  # Handle relative URLs
            print(img_url)
            
            # Extract subfolder from image URL if it contains a path
            img_path_parts = img_url.replace(url, "").lstrip("/").split("/")
            subfolder = os.path.join(folder, *img_path_parts[:-1])
            
            if not os.path.exists(subfolder):
                os.makedirs(subfolder)
            
            img_name = os.path.join(subfolder, img_path_parts[-1])
            
            try:
                img_data = requests.get(img_url, headers=headers).content
                with open(img_name, "wb") as img_file:
                    img_file.write(img_data)
                print(f"Downloaded: {img_name}")
            except Exception as e:
                print(f"Failed to download {img_url}: {e}")

# Replace with the target URL
url = 'https://spacingtech.com/html/medist/medist/'
download_images(url)
# Out:
# https://spacingtech.com/html/medist/medist/assets/image/index/logo.png
# Downloaded: image/assets/image/index/logo.png
# https://spacingtech.com/html/medist/medist/assets/image/index/newsletter-popup.jpg
# Downloaded: image/assets/image/index/newsletter-popup.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/logo.png
# Downloaded: image/assets/image/index/logo.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon1.png
# Downloaded: image/assets/image/index/menu/menu-icon1.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon2.png
# Downloaded: image/assets/image/index/menu/menu-icon2.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon3.png
# Downloaded: image/assets/image/index/menu/menu-icon3.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon4.png
# Downloaded: image/assets/image/index/menu/menu-icon4.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon5.png
# Downloaded: image/assets/image/index/menu/menu-icon5.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon6.png
# Downloaded: image/assets/image/index/menu/menu-icon6.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon7.png
# Downloaded: image/assets/image/index/menu/menu-icon7.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon8.png
# Downloaded: image/assets/image/index/menu/menu-icon8.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon9.png
# Downloaded: image/assets/image/index/menu/menu-icon9.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon10.png
# Downloaded: image/assets/image/index/menu/menu-icon10.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon11.png
# Downloaded: image/assets/image/index/menu/menu-icon11.png
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner1.jpg
# Downloaded: image/assets/image/menu/menu-banner1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner2.jpg
# Downloaded: image/assets/image/menu/menu-banner2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner3.jpg
# Downloaded: image/assets/image/menu/menu-banner3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner4.jpg
# Downloaded: image/assets/image/menu/menu-banner4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner5.jpg
# Downloaded: image/assets/image/menu/menu-banner5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/menu/menu-banner6.jpg
# Downloaded: image/assets/image/menu/menu-banner6.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-banner-product.jpg
# Downloaded: image/assets/image/index/menu/menu-banner-product.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/slider-1.jpg
# Downloaded: image/assets/image/index/slider-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/slider-mobile1.jpg
# Downloaded: image/assets/image/index/slider-mobile1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/slider-2.jpg
# Downloaded: image/assets/image/index/slider-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/slider-mobile2.jpg
# Downloaded: image/assets/image/index/slider-mobile2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-1.png
# Downloaded: image/assets/image/collection/collection-1.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-2.png
# Downloaded: image/assets/image/collection/collection-2.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-3.png
# Downloaded: image/assets/image/collection/collection-3.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-4.png
# Downloaded: image/assets/image/collection/collection-4.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-5.png
# Downloaded: image/assets/image/collection/collection-5.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-6.png
# Downloaded: image/assets/image/collection/collection-6.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-7.png
# Downloaded: image/assets/image/collection/collection-7.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-8.png
# Downloaded: image/assets/image/collection/collection-8.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-9.png
# Downloaded: image/assets/image/collection/collection-9.png
# https://spacingtech.com/html/medist/medist/assets/image/collection/collection-10.png
# Downloaded: image/assets/image/collection/collection-10.png
# https://spacingtech.com/html/medist/medist/assets/image/index/banner-1.jpg
# Downloaded: image/assets/image/index/banner-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/banner-2.jpg
# Downloaded: image/assets/image/index/banner-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/service-1.jpg
# Downloaded: image/assets/image/index/service-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/service-2.jpg
# Downloaded: image/assets/image/index/service-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/service-3.jpg
# Downloaded: image/assets/image/index/service-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-1.jpg
# Downloaded: image/assets/image/index/product/p-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-2.jpg
# Downloaded: image/assets/image/index/product/p-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-3.jpg
# Downloaded: image/assets/image/index/product/p-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-4.jpg
# Downloaded: image/assets/image/index/product/p-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-5.jpg
# Downloaded: image/assets/image/index/product/p-5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-6.jpg
# Downloaded: image/assets/image/index/product/p-6.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-7.jpg
# Downloaded: image/assets/image/index/product/p-7.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-8.jpg
# Downloaded: image/assets/image/index/product/p-8.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-9.jpg
# Downloaded: image/assets/image/index/product/p-9.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-10.jpg
# Downloaded: image/assets/image/index/product/p-10.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-11.jpg
# Downloaded: image/assets/image/index/product/p-11.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-12.jpg
# Downloaded: image/assets/image/index/product/p-12.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-13.jpg
# Downloaded: image/assets/image/index/product/p-13.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-14.jpg
# Downloaded: image/assets/image/index/product/p-14.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-15.jpg
# Downloaded: image/assets/image/index/product/p-15.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-16.jpg
# Downloaded: image/assets/image/index/product/p-16.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-17.jpg
# Downloaded: image/assets/image/index/product/p-17.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-18.jpg
# Downloaded: image/assets/image/index/product/p-18.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-19.jpg
# Downloaded: image/assets/image/index/product/p-19.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-20.jpg
# Downloaded: image/assets/image/index/product/p-20.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-21.jpg
# Downloaded: image/assets/image/index/product/p-21.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-22.jpg
# Downloaded: image/assets/image/index/product/p-22.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-23.jpg
# Downloaded: image/assets/image/index/product/p-23.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-24.jpg
# Downloaded: image/assets/image/index/product/p-24.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-1.jpg
# Downloaded: image/assets/image/index/product/p-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-2.jpg
# Downloaded: image/assets/image/index/product/p-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-3.jpg
# Downloaded: image/assets/image/index/product/p-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-4.jpg
# Downloaded: image/assets/image/index/product/p-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-5.jpg
# Downloaded: image/assets/image/index/product/p-5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-6.jpg
# Downloaded: image/assets/image/index/product/p-6.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-7.jpg
# Downloaded: image/assets/image/index/product/p-7.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-8.jpg
# Downloaded: image/assets/image/index/product/p-8.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-9.jpg
# Downloaded: image/assets/image/index/product/p-9.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-10.jpg
# Downloaded: image/assets/image/index/product/p-10.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-11.jpg
# Downloaded: image/assets/image/index/product/p-11.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-12.jpg
# Downloaded: image/assets/image/index/product/p-12.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/support.jpg
# Downloaded: image/assets/image/index/support.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-13.jpg
# Downloaded: image/assets/image/index/product/p-13.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-14.jpg
# Downloaded: image/assets/image/index/product/p-14.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-15.jpg
# Downloaded: image/assets/image/index/product/p-15.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-16.jpg
# Downloaded: image/assets/image/index/product/p-16.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-17.jpg
# Downloaded: image/assets/image/index/product/p-17.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-18.jpg
# Downloaded: image/assets/image/index/product/p-18.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-19.jpg
# Downloaded: image/assets/image/index/product/p-19.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-20.jpg
# Downloaded: image/assets/image/index/product/p-20.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-21.jpg
# Downloaded: image/assets/image/index/product/p-21.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-22.jpg
# Downloaded: image/assets/image/index/product/p-22.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-23.jpg
# Downloaded: image/assets/image/index/product/p-23.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/product/p-24.jpg
# Downloaded: image/assets/image/index/product/p-24.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/testi-1.jpg
# Downloaded: image/assets/image/index/testi-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/testi-2.jpg
# Downloaded: image/assets/image/index/testi-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/testi-3.jpg
# Downloaded: image/assets/image/index/testi-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/testi-4.jpg
# Downloaded: image/assets/image/index/testi-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-1.jpg
# Downloaded: image/assets/image/index/article/a-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-2.jpg
# Downloaded: image/assets/image/index/article/a-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-3.jpg
# Downloaded: image/assets/image/index/article/a-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-4.jpg
# Downloaded: image/assets/image/index/article/a-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-5.jpg
# Downloaded: image/assets/image/index/article/a-5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/article/a-6.jpg
# Downloaded: image/assets/image/index/article/a-6.jpg
# https://spacingtech.com/html/medist/medist/assets/image/index/logo.png
# Downloaded: image/assets/image/index/logo.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-american.png
# Downloaded: image/assets/image/other/paying-american.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-club.png
# Downloaded: image/assets/image/other/paying-club.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-discover.png
# Downloaded: image/assets/image/other/paying-discover.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-maestro.png
# Downloaded: image/assets/image/other/paying-maestro.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-paypal.png
# Downloaded: image/assets/image/other/paying-paypal.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-visa.png
# Downloaded: image/assets/image/other/paying-visa.png
# https://spacingtech.com/html/medist/medist/assets/image/product/p-1.jpg
# Downloaded: image/assets/image/product/p-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-2.jpg
# Downloaded: image/assets/image/product/p-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-3.jpg
# Downloaded: image/assets/image/product/p-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-4.jpg
# Downloaded: image/assets/image/product/p-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-5.jpg
# Downloaded: image/assets/image/product/p-5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-1.jpg
# Downloaded: image/assets/image/product/p-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-2.jpg
# Downloaded: image/assets/image/product/p-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-3.jpg
# Downloaded: image/assets/image/product/p-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-4.jpg
# Downloaded: image/assets/image/product/p-4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/product/p-5.jpg
# Downloaded: image/assets/image/product/p-5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-american.png
# Downloaded: image/assets/image/other/paying-american.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-club.png
# Downloaded: image/assets/image/other/paying-club.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-discover.png
# Downloaded: image/assets/image/other/paying-discover.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-maestro.png
# Downloaded: image/assets/image/other/paying-maestro.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-paypal.png
# Downloaded: image/assets/image/other/paying-paypal.png
# https://spacingtech.com/html/medist/medist/assets/image/other/paying-visa.png
# Downloaded: image/assets/image/other/paying-visa.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon1.png
# Downloaded: image/assets/image/index/menu/menu-icon1.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon2.png
# Downloaded: image/assets/image/index/menu/menu-icon2.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon3.png
# Downloaded: image/assets/image/index/menu/menu-icon3.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon4.png
# Downloaded: image/assets/image/index/menu/menu-icon4.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon5.png
# Downloaded: image/assets/image/index/menu/menu-icon5.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon6.png
# Downloaded: image/assets/image/index/menu/menu-icon6.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon7.png
# Downloaded: image/assets/image/index/menu/menu-icon7.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon8.png
# Downloaded: image/assets/image/index/menu/menu-icon8.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon9.png
# Downloaded: image/assets/image/index/menu/menu-icon9.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon10.png
# Downloaded: image/assets/image/index/menu/menu-icon10.png
# https://spacingtech.com/html/medist/medist/assets/image/index/menu/menu-icon11.png
# Downloaded: image/assets/image/index/menu/menu-icon11.png
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product1.jpg
# Downloaded: image/assets/image/search/search-product1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product2.jpg
# Downloaded: image/assets/image/search/search-product2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product3.jpg
# Downloaded: image/assets/image/search/search-product3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product4.jpg
# Downloaded: image/assets/image/search/search-product4.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product5.jpg
# Downloaded: image/assets/image/search/search-product5.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product6.jpg
# Downloaded: image/assets/image/search/search-product6.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product7.jpg
# Downloaded: image/assets/image/search/search-product7.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product8.jpg
# Downloaded: image/assets/image/search/search-product8.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product9.jpg
# Downloaded: image/assets/image/search/search-product9.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product10.jpg
# Downloaded: image/assets/image/search/search-product10.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product11.jpg
# Downloaded: image/assets/image/search/search-product11.jpg
# https://spacingtech.com/html/medist/medist/assets/image/search/search-product12.jpg
# Downloaded: image/assets/image/search/search-product12.jpg
# https://spacingtech.com/html/medist/medist/assets/image/cart/cart-1.jpg
# Downloaded: image/assets/image/cart/cart-1.jpg
# https://spacingtech.com/html/medist/medist/assets/image/cart/cart-2.jpg
# Downloaded: image/assets/image/cart/cart-2.jpg
# https://spacingtech.com/html/medist/medist/assets/image/cart/cart-3.jpg
# Downloaded: image/assets/image/cart/cart-3.jpg
# https://spacingtech.com/html/medist/medist/assets/image/cart/cart-4.jpg
# Downloaded: image/assets/image/cart/cart-4.jpg
